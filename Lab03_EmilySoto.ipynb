# %%
import pandas as pd

# %%
import mysql.connector
from mysql.connector import Error

def create_connection(host_name, user_name, user_password):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password
        )
        print("Connection to MySQL DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
host = "relational.fit.cvut.cz"
user = "guest"
pwd = "relational"
connection = create_connection(host_name = host, user_name =user ,user_password = pwd)
# Out:
# Connection to MySQL DB successful

# %% [markdown]
# # Parte 1

# %% [markdown]
# ### Pregunta 1
# 1.	Obtener el nombre, apellido, salario, título y vigencia del mismo para el empleado 12557. Su resultado se debe de ver de la siguiente manera:

# %%
query = """
            SELECT
                A.emp_no,
                A.first_name,
                A.last_name,
                B.title,
                C.from_date,
                C.to_date,
                C.salary
         FROM employee.employees A  
         LEFT JOIN employee.titles B on A.emp_no = B.emp_no 
         LEFT JOIN employee.salaries C on C.emp_no=A.emp_no
         WHERE A.emp_no = 12557
"""
emp_12557 = pd.read_sql(query,connection)
emp_12557
# Out:
#     emp_no first_name last_name            title   from_date     to_date  \
# 0    12557   Stafford    Kopetz  Senior Engineer  1988-03-20  1989-03-20
# 1    12557   Stafford    Kopetz  Senior Engineer  1989-03-20  1990-03-20
# 2    12557   Stafford    Kopetz  Senior Engineer  1990-03-20  1991-03-20
# 3    12557   Stafford    Kopetz  Senior Engineer  1991-03-20  1992-03-19
# 4    12557   Stafford    Kopetz  Senior Engineer  1992-03-19  1993-03-19
# 5    12557   Stafford    Kopetz  Senior Engineer  1993-03-19  1994-03-19
# 6    12557   Stafford    Kopetz  Senior Engineer  1994-03-19  1995-03-19
# 7    12557   Stafford    Kopetz  Senior Engineer  1995-03-19  1996-03-18
# 8    12557   Stafford    Kopetz  Senior Engineer  1996-03-18  1997-03-18
# 9    12557   Stafford    Kopetz  Senior Engineer  1997-03-18  1998-03-18
# 10   12557   Stafford    Kopetz  Senior Engineer  1998-03-18  1999-03-18
# 11   12557   Stafford    Kopetz  Senior Engineer  1999-03-18  2000-03-17
# 12   12557   Stafford    Kopetz  Senior Engineer  2000-03-17  2001-03-17
# 13   12557   Stafford    Kopetz  Senior Engineer  2001-03-17  2002-03-17
# 14   12557   Stafford    Kopetz  Senior Engineer  2002-03-17  9999-01-01
#
#     salary
# 0    41840
# 1    46021
# 2    48699
# 3    51610
# 4    51351
# 5    51660
# 6    52878
# 7    54053
# 8    57950
# 9    58055
# 10   58863
# 11   60447
# 12   60959
# 13   62951
# 14   64554

# %% [markdown]
# ### Pregunta 2
# 2.	Encontrar el último departamento en el que trabajó el empleado con la siguiente información del mismo: nombre, apellido, número de empleado, fecha de nacimiento, código de departamento, nombre del departamento, fecha cuando inició su trabajo en ese departamento y la fecha cuando concluyó su trabajo

# %%
query = """
        SELECT 
        B.first_name,
        B.last_name,
        B.birth_date,
        C.dept_name,
        A.* 
       FROM (
           SELECT
            dept_no
            ,emp_no
            ,MAX(from_date) Last_dept_date
            ,to_date
            FROM employee.dept_emp
            GROUP BY 1,2,4) A
       LEFT JOIN employee.employees B on A.emp_no = B.emp_no 
       LEFT JOIN employee.departments C ON C.dept_no = A.dept_no
       LIMIT 100
"""
last_dept=pd.read_sql(query,connection)
last_dept
# Out:
#    first_name    last_name  birth_date  dept_name dept_no  emp_no  \
# 0   Cristinel    Bouloucos  1958-07-06  Marketing    d001   10017
# 1      Georgy       Dredge  1956-06-06  Marketing    d001   10055
# 2     Berhard     McFarlin  1954-10-01  Marketing    d001   10058
# 3      Lunjin       Giveon  1952-04-07  Marketing    d001   10108
# 4       Yucel        Auria  1957-03-11  Marketing    d001   10140
# ..        ...          ...         ...        ...     ...     ...
# 95  Felicidad        Auria  1964-10-07  Marketing    d001   11744
# 96   Bingning       Etalle  1964-11-11  Marketing    d001   11752
# 97   Giordano     Zaccaria  1961-10-20  Marketing    d001   11776
# 98     Sarita        Birch  1963-11-12  Marketing    d001   11786
# 99     Chenxi  Thambidurai  1954-08-12  Marketing    d001   11797
#
#    Last_dept_date     to_date
# 0      1993-08-03  9999-01-01
# 1      1992-04-27  1995-07-22
# 2      1988-04-25  9999-01-01
# 3      1999-12-06  2001-10-20
# 4      1991-03-14  9999-01-01
# ..            ...         ...
# 95     1989-08-23  2000-01-18
# 96     1992-11-10  9999-01-01
# 97     1986-11-05  1999-11-01
# 98     1996-02-28  9999-01-01
# 99     1996-09-28  9999-01-01
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Pregunta 3
# 3.	Encontrar el salario máximo de cada empleado utilizando la función Partition By con toda la información del empleado y de su salario

# %%
query = """
    SELECT *
    FROM (
        SELECT
            A.emp_no
            ,A.birth_date
            ,A.first_name
            ,A.last_name
            ,A.gender
            ,D.dept_name
            ,B.salary
            ,ROW_NUMBER() OVER (PARTITION BY A.emp_no ORDER BY B.from_date DESC) AS seq
        FROM employee.employees A
        LEFT JOIN employee.salaries B ON B.emp_no = A.emp_no
        LEFT JOIN employee.dept_emp C ON C.emp_no = A.emp_no
        LEFT JOIN employee.departments D ON D.dept_no = C.dept_no
        GROUP BY 1,2,3,4,5,6,7
    ) A
    WHERE seq = 1
    LIMIT 100
"""
pd.read_sql(query,connection)
# Out:
#     emp_no  birth_date   first_name    last_name gender         dept_name  \
# 0    10001  1953-09-02       Georgi      Facello      M       Development
# 1    10002  1964-06-02      Bezalel       Simmel      F             Sales
# 2    10003  1959-12-03        Parto      Bamford      M        Production
# 3    10004  1954-05-01    Chirstian      Koblick      M        Production
# 4    10005  1955-01-21      Kyoichi     Maliniak      M   Human Resources
# ..     ...         ...          ...          ...    ...               ...
# 95   10096  1954-09-16       Jayson      Mandell      M        Production
# 96   10097  1952-02-27        Remzi  Waschkowski      M          Research
# 97   10098  1961-09-23  Sreekrishna    Servieres      F  Customer Service
# 98   10099  1956-05-25       Valter      Sullins      F             Sales
# 99   10100  1953-04-21     Hironobu    Haraldson      F   Human Resources
#
#     salary  seq
# 0    88958    1
# 1    72527    1
# 2    43311    1
# 3    74057    1
# 4    94692    1
# ..     ...  ...
# 95   68612    1
# 96   70161    1
# 97   56202    1
# 98   98538    1
# 99   74957    1
#
# [100 rows x 8 columns]

# %% [markdown]
# # Parte 2

# %%
import sqlite3

# %%
con = sqlite3.connect(r'C:\Users\Emily Soto\Desktop\Data Science\DW\sql-murder-mystery.db')

# %%
query = """
SELECT name 
  FROM sqlite_master
 where type = 'table'
 
 """
pd.read_sql(query, con)
# Out:
#                      name
# 0      crime_scene_report
# 1         drivers_license
# 2                  person
# 3  facebook_event_checkin
# 4               interview
# 5      get_fit_now_member
# 6    get_fit_now_check_in
# 7                  income
# 8                solution

# %%
query='''SELECT *
     FROM crime_scene_report
     WHERE date=20180115 AND city="SQL City"
     '''
pd.read_sql(query,con)
#Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
# Out:
#        date     type                                        description  \
# 0  20180115  assault  Hamilton: Lee, do you yield? Burr: You shot hi...
# 1  20180115  assault                                   Report Not Found
# 2  20180115   murder  Security footage shows that there were 2 witne...
#
#        city
# 0  SQL City
# 1  SQL City
# 2  SQL City

# %%
##testigo 1
query='''SELECT *,
     MAX(address_number) Last_house
     FROM person
     WHERE address_street_name="Northwestern Dr"
     
     '''
pd.read_sql(query,con)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#          ssn  Last_house
# 0  111564949        4919

# %%
##Testigo 2
query='''SELECT *
     FROM person
     WHERE address_street_name="Franklin Ave" AND name="Annabel Miller"
     
     '''
pd.read_sql(query,con)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %%
query='''SELECT *
     FROM drivers_license
     WHERE (id=490173 OR id=118009)
     
     '''
#WHERE date=20180115 AND city="SQL City"
pd.read_sql(query,con)
# Out:
#        id  age  height eye_color hair_color  gender plate_number  \
# 0  118009   64      84      blue      white    male       00NU00
# 1  490173   35      65     green      brown  female       23AM98
#
#         car_make car_model
# 0  Mercedes-Benz   E-Class
# 1         Toyota     Yaris

# %%
query='''SELECT *
     FROM interview
     WHERE person_id=16371 OR person_id=14887
     '''
#I recognized the killer from my gym when I was working out last week on January the 9th.
# He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z".
#Only gold members have those bags. The man got into a car with a plate that included "H42W".
pd.read_sql(query,con)
# Out:
#    person_id                                         transcript
# 0      14887  I heard a gunshot and then saw a man run out. ...
# 1      16371  I saw the murder happen, and I recognized the ...

# %%
query='''SELECT *
     FROM get_fit_now_check_in
     WHERE check_in_date=20180109 and membership_id="48Z55"
     '''
pd.read_sql(query,con)
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         48Z55       20180109           1530            1700

# %%
##Sicario
query='''SELECT *
     FROM get_fit_now_member
     WHERE id="48Z55"
     '''
pd.read_sql(query,con)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z55      67318  Jeremy Bowers               20160101              gold

# %%
query='''SELECT *
     FROM person
     WHERE id=67318
     '''
pd.read_sql(query,con)
# Out:
#       id           name  license_id  address_number    address_street_name  \
# 0  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#          ssn
# 0  871539279

# %%
query='''SELECT *
     FROM drivers_license
     WHERE (id=423327)
     '''
pd.read_sql(query,con)
# Out:
#        id  age  height eye_color hair_color gender plate_number   car_make  \
# 0  423327   30      70     brown      brown   male       0H42W2  Chevrolet
#
#   car_model
# 0  Spark LS

# %%
cursor = con.cursor()
sql = "INSERT INTO solution VALUES (1, 'Jeremy Bowers')"
cursor.execute(sql)
con.commit()
var = pd.read_sql("SELECT value FROM solution", con)
var.iloc[0,0]
# Out:
# "Congrats, you found the murderer! But wait, there's more... If you think you're up for a challenge, try querying the interview transcript of the murderer to find the real villian behind this crime. If you feel especially confident in your SQL skills, try to complete this final step with no more than 2 queries. Use this same INSERT statement with your new suspect to check your answer."

# %%
##Cómplice
query='''SELECT *
     FROM interview
     WHERE person_id=67318
     '''
pd.read_sql(query,con)
#I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67").
#She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017
# Out:
#    person_id                                         transcript
# 0      67318  I was hired by a woman with a lot of money. I ...

# %%
query='''
    SELECT *
    FROM (
        SELECT
            A.height
            ,A.hair_color
            ,A.gender
            ,A.car_model
            ,B.id
            ,B.name
        FROM drivers_license A
        LEFT JOIN person B on A.id = B.license_id
        GROUP BY 1,2,3,4,5,6
    ) A
    WHERE (A.hair_color="red" AND A.gender="female" AND A.car_model="Model S") AND A.height BETWEEN 65 AND 67
     '''
pd.read_sql(query,con)
# Out:
#    height hair_color  gender car_model     id              name
# 0      65        red  female   Model S  78881          Red Korb
# 1      66        red  female   Model S  90700     Regina George
# 2      66        red  female   Model S  99716  Miranda Priestly

# %%
query='''SELECT 
    person_id,
    event_name,
    count(person_id) as Veces
    FROM facebook_event_checkin
    GROUP BY 1,2
    HAVING Veces>=3 AND (person_id=99716 OR person_id=90700)
     '''
pd.read_sql(query,con)
# Out:
#    person_id            event_name  Veces
# 0      99716  SQL Symphony Concert      3

# %%
cursor = con.cursor()
sql = "INSERT INTO solution VALUES (1, 'Miranda Priestly')"
cursor.execute(sql)
con.commit()
var = pd.read_sql("SELECT value FROM solution", con)
var.iloc[0,0]
# Out:
# 'Congrats, you found the brains behind the murder! Everyone in SQL City hails you as the greatest SQL detective of all time. Time to break out the champagne!'
